# %%
import matplotlib.patches as mpatches
from pathlib import Path
import xarray as xr
from statsmodels.formula.api import ols
import geopandas as gpd
import pandas as pd
import dask.dataframe as dd
from matplotlib import pyplot as plt
import seaborn as sns
from warnings import warn
from tqdm import tqdm
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error
from LAD import LAD
from LAD.util import loadR21_CH4, loadBAWLD_CH4

# %%
# loadR21_CH4()
r21 = pd.read_csv('/Volumes/thebe/Other/Rosentreter2021/edk_out/Rosentreter_Aquatic_Ecosystems_lakes_temps.csv')

# %%
## Ourb reported water temperature and reanalysis soil temperature correlated
sns.scatterplot(r21, x='Tw_degc', y='ERA5_stl1')
# Out:
# /Users/ekyzivat/mambaforge/envs/geo/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ekyzivat/mambaforge/envs/geo/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Tw_degc', ylabel='ERA5_stl1'>

# %%
## Is there an offset between these temperatures once I convert to K?
sns.set_style('whitegrid')
plt.scatter(r21.Tw_degc+273.15, r21.ERA5_stl1)
plt.plot([270, 315], [270, 315], '-k', alpha=0.6)
plt.xlabel('Water T (K)')
plt.ylabel('Reanalysis soil T (K)')
# Out:
# Text(0, 0.5, 'Reanalysis soil T (K)')

# %% [markdown]
# Water temperature is about 10° warmer in the coolest climates, and approximately equal to annual soil temperature in the tropical climates.
